# %%
import pandas as pd

# %%
df = pd.read_json("/home/mapa/Documents/Tec/7S/IA-Avanzada/IA-Avanzada-2/FinalProject/AI-pico-banana-project/dev/data/open-image-mapping-resources/sft_with_local_source_image_path.jsonl ", lines=True)

print(df.shape)
# Out:
# (257730, 6)

# %%
print(df.columns)
# Out:
# Index(['open_image_input_url', 'text', 'output_image', 'edit_type',
#        'summarized_text', 'local_input_image'],
#       dtype='object')

# %%
print(df["output_image"])
# Out:
# 0                     images/positive-edit/1.png
# 1                     images/positive-edit/2.png
# 2                     images/positive-edit/3.png
# 3                     images/positive-edit/6.png
# 4                     images/positive-edit/7.png
#                            ...
# 257725    images/positive-edit/kewsft_retry2.png
# 257726           images/positive-edit/322746.png
# 257727    images/positive-edit/kewsfw_retry2.png
# 257728    images/positive-edit/kewsf6_retry2.png
# 257729           images/positive-edit/322750.png
# Name: output_image, Length: 257730, dtype: object

# %%
print(df.head(1))
# Out:
#                                 open_image_input_url  \
# 0  https://c1.staticflickr.com/8/7404/9423051591_...
#
#                                                 text  \
# 0  Remove the red flag and its white pole from th...
#
#                  output_image                  edit_type  \
# 0  images/positive-edit/1.png  Remove an existing object
#
#                                      summarized_text  \
# 0  Flag removed; extend sky, dune, and fence seam...
#
#                                    local_input_image
# 0  /home/mapa/Documents/Tec/7S/IA-Avanzada/IA-Ava...

# %%
print(df.iloc[0,1])
# Out:
# Remove the red flag and its white pole from the upper right of the image, seamlessly extending the clear blue sky, the sandy dune with its subtle texture, and the wooden fence to fill the void, ensuring the lighting, color, and natural grain of the background are perfectly matched for a realistic and unblemished result.
