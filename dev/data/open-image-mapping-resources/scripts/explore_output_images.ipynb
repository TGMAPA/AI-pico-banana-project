# %%
import pandas as pd

# %%
df = pd.read_csv("/home/mapa/Documents/Tec/7S/IA-Avanzada/IA-Avanzada-2/FinalProject/AI-pico-banana-project/dev/data/open-image-mapping-resources/source-info/filtered_sft_with_local_source_image_path.csv")

print(df.shape)
# Out:
# (21896, 7)

# %%
df["output_image"]
# Out:
# 0                   images/positive-edit/32.png
# 1                   images/positive-edit/40.png
# 2                   images/positive-edit/44.png
# 3                  images/positive-edit/329.png
# 4                  images/positive-edit/347.png
#                           ...
# 21891           images/positive-edit/265746.png
# 21892    images/positive-edit/kews1u_retry1.png
# 21893           images/positive-edit/260017.png
# 21894           images/positive-edit/260024.png
# 21895           images/positive-edit/260034.png
# Name: output_image, Length: 21896, dtype: object

# %%
df["output_image"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["output_image"].str.startswith("images/positive-edit/").all()
# Out:
# np.True_
