# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_local_map = pd.read_json("data/open-image-mapping-resources/sft_with_local_source_image_path.jsonl", lines=True)


df_output_json = pd.read_json("data/open-image-mapping-resources/preference.jsonl", lines=True)

# %%
print(df_local_map.shape, df_output_json.shape)
print("Localmap-Cols : ", list(df_local_map.columns))
print("OuputJson-Cols: ", list(df_output_json.columns))
# Out:
# (257730, 6) (56473, 6)
# Localmap-Cols :  ['open_image_input_url', 'text', 'output_image', 'edit_type', 'summarized_text', 'local_input_image']
# OuputJson-Cols:  ['output_image', 'rejected_images', 'text', 'edit_type', 'open_image_input_url', 'summarized_text']

# %%
df_output_json["edit_type"].hist(xrot=90)
plt.title('Histogram of edit_type')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent title overlap

plt.show()
# Out:
# /tmp/ipykernel_10426/97006297.py:5: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent title overlap
